# %% [markdown]
# # Data Generation
# Heston Model:
# $$dS_{t}={\sqrt  {V _{t}}}S_{t}\,dW_{t}, \ S_{0}=s_{0}>0$$
# $$dV _{t}=a (b -V _{t})\,dt+c {\sqrt  {V _{t}}}\,dZ_{t}, \ V_{0}=v_{0}>0$$
# Model Parameters:
# $$\theta = (a,b,c,\rho)$$

# %% [markdown]
# SABR Model:
# $$dS_{t}=V_{t}S_{t}^{\beta }\,dW_{t}, \ S_{0}=s_{0}>0,  \ \beta \in [0,1]$$
# $$dV_{t}=\alpha V_{t}^{}\,dZ_{t}, \ V_{0}=v_{0}>0$$
# Model Parameters:
# $$\theta = (\alpha,\beta,\rho)$$

# %% [markdown]
# Approch: Simulate market S for different parameters using Euler-Maruyama

# %% [markdown]
# Goal: function with input: $$\theta$$ and output: $$S(\{(strikes,maturities)\})$$

# %% [markdown]
# ## Brownian Motion

# %%
from math import sqrt
from scipy.stats import norm
import numpy as np

# %%
def brownian_motion(n, T, dim, out=None):
    dt = T/n
    
    r = norm.rvs(size=(dim,n+1) , scale=sqrt(dt))

    if out is None:
        out = np.zeros((dim,n+1))
        
    np.cumsum(r, axis=-1, out=out)
 
    return out

# %%
n=1000
T=2
dim=8

bm = brownian_motion(n,T,dim)
bm.shape
# Out:
# (8, 1001)

# %%
import matplotlib.pyplot as plt

# %%
for k in range(dim):    
    plt.plot(np.linspace(0,T,n+1), bm[k,:])

# %% [markdown]
# ## Correlated Brownian Motion

# %%
def corr_brownian_motion(n, T, dim, rho):
    dt = T/n

    dW1 = norm.rvs(size=(dim,n+1) , scale=sqrt(dt))
    dW2 = rho * dW1 + np.sqrt(1 - np.power(rho ,2)) * norm.rvs(size=(dim,n+1) , scale=sqrt(dt))
        
    W1 = np.cumsum(dW1, axis=-1)
    W2 = np.cumsum(dW2, axis=-1)
 
    return W1,W2

# %%
n=1000
T=2
dim=2
rho=-1

W,Z = corr_brownian_motion(n,T,dim,rho)
W.shape
# Out:
# (2, 1001)

# %%
for k in range(dim):    
    plt.plot(np.linspace(0,T,n+1), W[k,:], "r") 
    plt.plot(np.linspace(0,T,n+1), Z[k,:], "b")

# %% [markdown]
# ## Euler Maruyama and Milstein

# %% [markdown]
# For $${\mathrm  {d}}X_{t}=\mu(X_{t})\,{\mathrm  {d}}t+\sigma(X_{t})\,{\mathrm  {d}}W_{t}$$
# the Euler Maruyama method reads: $$\,Y_{{n+1}}=Y_{n}+\mu(Y_{n})\,\Delta t+\sigma(Y_{n})\,(W_{{\tau _{{n+1}}}}-W_{{\tau _{n}}})\, \
# with \ Y_{{0}} = X_{{0}}$$

# %%
from scipy.stats import norm
import numpy as np

# %%
def euler_maruyama(mu,sigma,T,x0,W):
    dim = W.shape[0]
    n = W.shape[1]-1
    Y = np.zeros((dim,n+1))
    dt = T/n
    sqrt_dt = np.sqrt(dt)
    for l in range(dim):
        Y[l,0] = x0
        for i in range(n):
            Y[l,i+1] = Y[l,i] + np.multiply(mu(Y[l,i],l,i),dt) + sigma(Y[l,i],l,i)*sqrt_dt*(W[l,i+1]-W[l,i])
    
    return Y

# %% [markdown]
# The Milstein method reads: $$\,Y_{{n+1}}=Y_{n}+\mu(Y_{n})\,\Delta t+\sigma(Y_{n})\,(W_{{\tau _{{n+1}}}}-W_{{\tau _{n}}}) +{\frac {1}{2}}\sigma(Y_{n})\sigma'(Y_{n})\left((W_{{\tau _{{n+1}}}}-W_{{\tau _{n}}})^{2}-\Delta t\right)\, \
# with \ Y_{{0}} = X_{{0}}$$

# %%
def milstein(mu,sigma,sigma_derivative,T,x0,W):
    dim = W.shape[0]
    n = W.shape[1]-1
    Y = np.zeros((dim,n+1))
    dt = T/n
    sqrt_dt = np.sqrt(dt)
    for l in range(dim):
        Y[l,0] = x0
        for i in range(n):
            Y[l,i+1] = Y[l,i] + mu(Y[l,i],l,i)*dt + np.multiply(sigma(Y[l,i],l,i)*sqrt_dt,(W[l,i+1]-W[l,i]))+0.5*sigma(Y[l,i],l,i)*sigma_derivative(Y[l,i],l,i)*(np.power((W[l,i+1]-W[l,i]),2)-dt)
    
    return Y

# %% [markdown]
# ## Heston Model

# %%
#work in progress
def heston(a,b,c,T,W,Z,V0,S0):
    #assert(2*a*b > c*c) 
    
    def mu2(V,i,k):
        return np.multiply(a,(b-V))
    
    def sigma2(V,i,k):
        return np.multiply(c,np.sqrt(np.maximum(0.0,V)))
    
    V = euler_maruyama(mu2,sigma2,T,V0,Z)
    
    def mu1(S,i,k):
        return 0.0
    
    def sigma1(S,i,k):
        return np.multiply(np.sqrt(np.maximum(0.0,V[i,k])),S)
    
    S = euler_maruyama(mu1,sigma1,T,S0,W)
    
    return S,V

# %% [markdown]
# ### Test

# %%
a=4
b=4
c=2
T=1
n=5000
dim=50
rho=-0.5

W,Z = corr_brownian_motion(n,T,dim,rho)
V0 = 2
S0 = 1

S,V = heston(a,b,c,T,W,Z,V0,S0)
S_T = S[:,n]
V_T = V[:,n]
S_T_mean = np.mean(S_T, axis=0)
V_T_mean = np.mean(V_T, axis=0)


print(S_T_mean)
print(V_T_mean)

for k in range(dim):    
    plt.plot(np.linspace(0,T,n+1), V[k,:],"r") 
    plt.plot(np.linspace(0,T,n+1), S[k,:], "b")
# Out:
# 1.0031434512800521
# 3.9637421023333475

# %% [markdown]
# Note: S_T (blue) does not seem to converge, something probably wrong
#
# Also: V seems to converge towards b, while S stays close to one(probably wrong)

# %%
def heston_milstein(a,b,c,T,W,Z,V0,S0):
    assert(2*a*b > c*c)
    
    def mu2(V,i,k):
        return np.multiply(a,(b-V))
    
    def sigma2(V,i,k):
        return np.multiply(c,np.sqrt(np.maximum(0.0,V))) #avoid taking square root of something negative
    
    def sigma_dev2(V,i,k):
        return c/2/np.sqrt(np.maximum(0.001,V)) #avoid dividing by to small numbers or even zero
    
    V = milstein(mu2,sigma2,sigma_dev2,T,V0,Z)
    
    def mu1(S,i,k):
        return 0.0
    
    def sigma1(S,i,k):
        return np.sqrt(np.maximum(0.0,V[i,k]))*S
    
    def sigma_dev1(S,i,k):
        return np.sqrt(np.maximum(0.0,V[i,k]))
    
    S = milstein(mu1,sigma1,sigma_dev1,T,S0,W)
    
    return S,V

# %% [markdown]
# ### Test

# %%
a=4
b=8
c=2
T=1
n=1000
dim=50
rho=-0.5

W,Z = corr_brownian_motion(n,T,dim,rho)
V0 = 2
S0 = 1

S,V = heston_milstein(a,b,c,T,W,Z,V0,S0)
S_T = S[:,n]
V_T = V[:,n]
S_T_mean = np.mean(S_T, axis=0)
V_T_mean = np.mean(V_T, axis=0)


print(S_T_mean)
print(V_T_mean)

for k in range(dim):    
    plt.plot(np.linspace(0,T,n+1), V[k,:],"r") 
    plt.plot(np.linspace(0,T,n+1), S[k,:], "b")
# Out:
# 1.0127457192808478
# 7.892312379585954

# %% [markdown]
# ## SABR Model

# %%
#work in progress

# %%
def sabr(alpha,beta,T,W,Z,V0,S0):
    assert(beta>0 and beta<1)

    def mu2(V,i,k):
        return 0.0
    
    def sigma2(V,i,k):
        return np.multiply(alpha,V)
    
    V = euler_maruyama(mu2,sigma2,T,V0,Z)
    
    def mu1(S,i,k):
        return 0.0
    
    def sigma1(S,i,k):
        return np.multiply(V[i,k],np.power(np.maximum(0.0,S),beta))
    
    S = euler_maruyama(mu1,sigma1,T,S0,W)
    
    return S,V

# %% [markdown]
# ### Test

# %%
alpha=1
beta=0.1
T=1
n=5000
dim=50
W=brownian_motion(n,T,dim)
Z=brownian_motion(n,T,dim)
V0 = 3
S0 = 10

S,V = sabr(alpha,beta,T,W,Z,V0,S0)
S_T = S[:,T]
V_T = V[:,T]
S_T_mean = np.mean(S_T, axis=0)
V_T_mean = np.mean(V_T, axis=0)


print(S_T_mean)
print(V_T_mean)

for k in range(dim):    
    plt.plot(np.linspace(0,T,n+1), V[k,:], "r") 
    plt.plot(np.linspace(0,T,n+1), S[k,:], "b")
# Out:
# 10.000032467420828
# 2.9998549681115834

# %% [markdown]
# ## Actually Generate Data
#
# Generate grid of input data. Use Pandas to write  data to csv

# %%
import pandas as pd #for writting to csv files

# %%
def heston_data(a_vals,b_vals,c_vals,rho_vals):
    num = a_vals.shape[0]
    
    data = np.zeros((num,6))
    data[:,0] = a_vals
    data[:,1] = b_vals
    data[:,2] = c_vals
    data[:,3] = rho_vals
    V0 = 1
    S0 = 1
    T = 1
    n = 1000
    dim = 10
    
    for i in range(num):
        W,Z = corr_brownian_motion(n,T,dim,rho_vals[i])
        S,V = heston(a_vals[i],b_vals[i],c_vals[i],T,W,Z,V0,S0)
        data[i,4] = np.mean(S[:,n])
        data[i,5] = np.mean(V[:,n])

    return data

# %%
#to ensure 2ab > c^2 let's use a,b~Uni(1,2) and c~Uni(0,1)
from scipy.stats import uniform


a = uniform.rvs(size=10)+1
b = uniform.rvs(size=10)+1
c = uniform.rvs(size=10)
rho = uniform.rvs(size=10)

data = heston_data(a,b,c,rho)
pd.DataFrame(data).to_csv("./data/heston_data.csv")

print(data[:10,:])
# Out:
# [[1.06909252 1.69782951 0.79689625 0.91316869 0.99661199 1.45561712]
#  [1.0621445  1.81065598 0.77951931 0.86662446 1.00370511 1.53071741]
#  [1.8854989  1.08815466 0.71527136 0.65961207 0.99317458 1.07573278]
#  [1.2545597  1.94167077 0.85298305 0.02804693 0.98535015 1.67598484]
#  [1.72587199 1.61902631 0.69059551 0.88494917 1.01228178 1.5117122 ]
#  [1.17643631 1.02855037 0.09902218 0.99969951 0.99760607 1.01935935]
#  [1.41951988 1.19610402 0.78084289 0.74112787 0.98096305 1.14155644]
#  [1.85167573 1.20876663 0.08081648 0.85981772 0.99446879 1.17627507]
#  [1.21847338 1.7788606  0.7253086  0.28909781 0.99459352 1.54805432]
#  [1.05654739 1.70282409 0.88530232 0.02382321 0.99384766 1.45523932]]
